# %%
import os
main_directory = "./AirPolution_Taiwan"
year_file = os.listdir(main_directory)
print(year_file)
# Out:
# ['2016', '2017', '2018']

# %%
for year in year_file:
    coun_path = os.path.join(main_directory, year)
    print("path="+coun_path)
    coun_file = os.listdir(coun_path)
    print(coun_file)
    print("\n")
    for country in coun_file:
        station_path = os.path.join(coun_path, country)
        print(station_path)
        station_file=os.listdir(station_path)
        i=0;
        for station in station_file:
            if station.endswith(".xls"):
                i+=1
                dst=country+str(i)+".xls"
                src=os.path.join(station_path,station)
                dst=os.path.join(station_path,dst)
                os.rename(src,dst)
                print(station)
        print("\n")
# Out:
# path=./AirPolution_Taiwan/2016
# ['Hualien', 'Taipei', 'Hsinchu', 'Matsu', 'Miaoli', 'Kinmen', 'Pingtung', 'Taitung', 'Chiayi', 'Tainan', 'Taoyuan', 'Yunlin', 'Penghu', 'Kaohsiung', 'Nantou', 'Taichung', 'Keelung', 'Yilan', 'New_Taipei', 'Changhua']
#
#
# ./AirPolution_Taiwan/2016/Hualien
# Hualien1.xls
#
#
# ./AirPolution_Taiwan/2016/Taipei
# Taipei1.xls
# Taipei4.xls
# Taipei3.xls
# Taipei2.xls
#
#
# ./AirPolution_Taiwan/2016/Hsinchu
# Hsinchu2.xls
# Hsinchu1.xls
#
#
# ./AirPolution_Taiwan/2016/Matsu
# Matsu1.xls
#
#
# ./AirPolution_Taiwan/2016/Miaoli
# Miaoli1.xls
#
#
# ./AirPolution_Taiwan/2016/Kinmen
# Kinmen1.xls
#
#
# ./AirPolution_Taiwan/2016/Pingtung
# Pingtung1.xls
# Pingtung2.xls
#
#
# ./AirPolution_Taiwan/2016/Taitung
# Taitung1.xls
#
#
# ./AirPolution_Taiwan/2016/Chiayi
# Chiayi2.xls
# Chiayi1.xls
#
#
# ./AirPolution_Taiwan/2016/Tainan
# Tainan2.xls
# Tainan3.xls
# Tainan1.xls
#
#
# ./AirPolution_Taiwan/2016/Taoyuan
# Taoyuan1.xls
# Taoyuan5.xls
# Taoyuan3.xls
# Taoyuan4.xls
# Taoyuan2.xls
#
#
# ./AirPolution_Taiwan/2016/Yunlin
# Yunlin2.xls
# Yunlin1.xls
#
#
# ./AirPolution_Taiwan/2016/Penghu
# Penghu1.xls
#
#
# ./AirPolution_Taiwan/2016/Kaohsiung
# Kaohsiung7.xls
# Kaohsiung1.xls
# Kaohsiung6.xls
# Kaohsiung2.xls
# Kaohsiung3.xls
# Kaohsiung5.xls
# Kaohsiung4.xls
#
#
# ./AirPolution_Taiwan/2016/Nantou
# Nantou2.xls
# Nantou1.xls
#
#
# ./AirPolution_Taiwan/2016/Taichung
# Taichung1.xls
# Taichung2.xls
# Taichung3.xls
#
#
# ./AirPolution_Taiwan/2016/Keelung
# Keelung1.xls
#
#
# ./AirPolution_Taiwan/2016/Yilan
# Yilan1.xls
#
#
# ./AirPolution_Taiwan/2016/New_Taipei
# New_Taipei4.xls
# New_Taipei6.xls
# New_Taipei5.xls
# New_Taipei7.xls
# New_Taipei1.xls
# New_Taipei2.xls
# New_Taipei3.xls
#
#
# ./AirPolution_Taiwan/2016/Changhua
# Changhua1.xls
#
#
# path=./AirPolution_Taiwan/2017
# ['Hualien', 'Taipei', 'Hsinchu', 'Matsu', 'Miaoli', 'Kinmen', 'Pingtung', 'Taitung', 'Chiayi', 'Tainan', 'Taoyuan', 'Yunlin', 'Penghu', 'Kaohsiung', 'Nantou', 'Taichung', 'Keelung', 'Yilan', 'New_Taipei', 'Changhua']
#
#
# ./AirPolution_Taiwan/2017/Hualien
# Hualien1.xls
#
#
# ./AirPolution_Taiwan/2017/Taipei
# Taipei1.xls
# Taipei4.xls
# Taipei3.xls
# Taipei2.xls
#
#
# ./AirPolution_Taiwan/2017/Hsinchu
# Hsinchu2.xls
# Hsinchu1.xls
#
#
# ./AirPolution_Taiwan/2017/Matsu
# Matsu1.xls
#
#
# ./AirPolution_Taiwan/2017/Miaoli
# Miaoli1.xls
#
#
# ./AirPolution_Taiwan/2017/Kinmen
# Kinmen1.xls
#
#
# ./AirPolution_Taiwan/2017/Pingtung
# Pingtung1.xls
# Pingtung2.xls
#
#
# ./AirPolution_Taiwan/2017/Taitung
# Taitung1.xls
#
#
# ./AirPolution_Taiwan/2017/Chiayi
# Chiayi2.xls
# Chiayi1.xls
#
#
# ./AirPolution_Taiwan/2017/Tainan
# Tainan2.xls
# Tainan3.xls
# Tainan1.xls
#
#
# ./AirPolution_Taiwan/2017/Taoyuan
# Taoyuan1.xls
# Taoyuan5.xls
# Taoyuan3.xls
# Taoyuan4.xls
# Taoyuan2.xls
#
#
# ./AirPolution_Taiwan/2017/Yunlin
# Yunlin2.xls
# Yunlin1.xls
#
#
# ./AirPolution_Taiwan/2017/Penghu
# Penghu1.xls
#
#
# ./AirPolution_Taiwan/2017/Kaohsiung
# Kaohsiung7.xls
# Kaohsiung1.xls
# Kaohsiung6.xls
# Kaohsiung2.xls
# Kaohsiung3.xls
# Kaohsiung5.xls
# Kaohsiung4.xls
#
#
# ./AirPolution_Taiwan/2017/Nantou
# Nantou2.xls
# Nantou1.xls
#
#
# ./AirPolution_Taiwan/2017/Taichung
# Taichung1.xls
# Taichung2.xls
# Taichung3.xls
#
#
# ./AirPolution_Taiwan/2017/Keelung
# Keelung1.xls
#
#
# ./AirPolution_Taiwan/2017/Yilan
# Yilan1.xls
#
#
# ./AirPolution_Taiwan/2017/New_Taipei
# New_Taipei4.xls
# New_Taipei6.xls
# New_Taipei5.xls
# New_Taipei7.xls
# New_Taipei1.xls
# New_Taipei2.xls
# New_Taipei3.xls
#
#
# ./AirPolution_Taiwan/2017/Changhua
# Changhua1.xls
#
#
# path=./AirPolution_Taiwan/2018
# ['Hualien', 'Taipei', 'Hsinchu', 'Matsu', 'Miaoli', 'Kinmen', 'Pingtung', 'Taitung', 'Chiayi', 'Tainan', 'Taoyuan', 'Yunlin', 'Penghu', 'Kaohsiung', 'Nantou', 'Taichung', 'Keelung', 'Yilan', 'New_Taipei', 'Changhua']
#
#
# ./AirPolution_Taiwan/2018/Hualien
# Hualien1.xls
#
#
# ./AirPolution_Taiwan/2018/Taipei
# Taipei1.xls
# Taipei2.xls
#
#
# ./AirPolution_Taiwan/2018/Hsinchu
# Hsinchu1.xls
#
#
# ./AirPolution_Taiwan/2018/Matsu
# Matsu1.xls
#
#
# ./AirPolution_Taiwan/2018/Miaoli
# Miaoli1.xls
# Miaoli2.xls
#
#
# ./AirPolution_Taiwan/2018/Kinmen
# Kinmen1.xls
#
#
# ./AirPolution_Taiwan/2018/Pingtung
# Pingtung1.xls
# Pingtung2.xls
#
#
# ./AirPolution_Taiwan/2018/Taitung
# Taitung1.xls
#
#
# ./AirPolution_Taiwan/2018/Chiayi
# Chiayi1.xls
#
#
# ./AirPolution_Taiwan/2018/Tainan
# Tainan1.xls
#
#
# ./AirPolution_Taiwan/2018/Taoyuan
# Taoyuan1.xls
# Taoyuan2.xls
#
#
# ./AirPolution_Taiwan/2018/Yunlin
# Yunlin1.xls
#
#
# ./AirPolution_Taiwan/2018/Penghu
# Penghu1.xls
#
#
# ./AirPolution_Taiwan/2018/Kaohsiung
# Kaohsiung1.xls
# Kaohsiung2.xls
#
#
# ./AirPolution_Taiwan/2018/Nantou
# Nantou1.xls
#
#
# ./AirPolution_Taiwan/2018/Taichung
# Taichung1.xls
# Taichung2.xls
#
#
# ./AirPolution_Taiwan/2018/Keelung
# Keelung1.xls
#
#
# ./AirPolution_Taiwan/2018/Yilan
# Yilan1.xls
#
#
# ./AirPolution_Taiwan/2018/New_Taipei
# New_Taipei1.xls
# New_Taipei2.xls
#
#
# ./AirPolution_Taiwan/2018/Changhua
# Changhua1.xls
# Changhua2.xls
